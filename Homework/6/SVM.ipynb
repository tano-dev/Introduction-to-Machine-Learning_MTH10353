# %%
pip install fg-data-profiling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.3/400.3 kB 7.3 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from data_profiling import ProfileReport
import pickle

# %%
# !gdown 1g4nkmLZ658A3Nq8uK7PtPVvVvcrknQor
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1g4nkmLZ658A3Nq8uK7PtPVvVvcrknQor
# To: /content/dibetes.csv
# 100% 122k/122k [00:00<00:00, 68.7MB/s]

# %%
df = pd.read_csv("./dibetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          4.0    117.0           64.0           27.0    120.0  33.2
# 1          2.0     91.0           62.0            0.0      0.0  27.3
# 2          5.0    101.0           68.0           47.0     71.0  30.2
# 3          2.0     99.0           52.0           15.0     94.0  24.6
# 4          2.0    130.0           74.0           55.0    100.0  33.6
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.230  24.0      0.0
# 1                     0.525  22.0      0.0
# 2                     0.364  24.0      0.0
# 3                     0.637  21.0      0.0
# 4                     0.404  23.0      0.0

# %% [markdown]
# * Pregnancies: Number of times pregnant
# * Glucose: Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# * BloodPressure: Diastolic blood pressure (mm Hg)
# * SkinThickness: Triceps skin fold thickness (mm)
# * Insulin: 2-Hour serum insulin (mu U/ml)
# * BMI: Body mass index (weight in kg/(height in m)^2)
# * DiabetesPedigreeFunction: Diabetes pedigree function
# * Age: Age (years)
# * Outcome: Class variable (0 or 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2666 entries, 0 to 2665
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               2666 non-null   float64
#  1   Glucose                   2661 non-null   float64
#  2   BloodPressure             2666 non-null   float64
#  3   SkinThickness             2666 non-null   float64
#  4   Insulin                   2666 non-null   float64
#  5   BMI                       2655 non-null   float64
#  6   DiabetesPedigreeFunction  2666 non-null   float64
#  7   Age                       2666 non-null   float64
#  8   Outcome                   2666 non-null   float64
# dtypes: float64(9)
# memory usage: 187.6 KB

# %%
print(df.isna().sum())
# Out:
# Pregnancies                  0
# Glucose                      5
# BloodPressure                0
# SkinThickness                0
# Insulin                      0
# BMI                         11
# DiabetesPedigreeFunction     0
# Age                          0
# Outcome                      0
# dtype: int64

# %%
ProfileReport(df, title="Profiling Report")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
df = df.drop_duplicates(ignore_index=True)

# %%
X = df.drop(columns=["Outcome"], axis=1)
y = df.Outcome
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=10, train_size=0.8)

# %%
X_train.head()
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 537           0.0    173.0           78.0           32.0    265.0  46.5
# 437           1.0    117.0           60.0           23.0    106.0  33.8
# 952           2.0    107.0           74.0           40.0    124.0  33.6
# 1409         11.0    120.0           80.0           43.0    231.0  42.3
# 2089         11.0    120.0           80.0           43.0    187.0  44.3
#
#       DiabetesPedigreeFunction   Age
# 537                      1.159  58.0
# 437                      0.466  27.0
# 952                      0.404  23.0
# 1409                     0.785  48.0
# 2089                     0.785  48.0

# %%
#Hàm để mình save lại được các imputer, scaler và model
def save(file, file_name):
    """
    input:
    #file: tên biến chứa model cần lưu
    #file_name: đường dẫn của model
    """
    pickle.dump(file, open(file_name, "wb"))

# %%
from sklearn.impute import SimpleImputer
#Biến những giá trị bằng 0 thành mean của các samples tập training
imputer = SimpleImputer(missing_values=0, strategy="mean")
zero_cols = ["BloodPressure", "Insulin", "SkinThickness"]
X_train.loc[:, zero_cols] = imputer.fit_transform(X_train[zero_cols])
X_test.loc[:, zero_cols] = imputer.transform(X_test[zero_cols])
save(imputer, "zero.sav")

#Biến những giá trị bằng nan thành mean của các samples tập training
imputer = SimpleImputer(missing_values=np.nan, strategy="mean")
nan_cols = ["Glucose", "BMI"]
X_train.loc[:, nan_cols] = imputer.fit_transform(X_train[nan_cols])
X_test.loc[:, nan_cols] = imputer.transform(X_test[nan_cols])
save(imputer, "nan.sav")

#https://scikit-learn.org/stable/api/sklearn.impute.html

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_normalized_train = scaler.fit_transform(X_train)
X_normalized_test = scaler.fit(X_test)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.svm import SVC
pipe_line = make_pipeline(StandardScaler(), SVC())
pipe_line.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()), ('svc', SVC())])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, pipe_line.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.96      0.94       254
#          1.0       0.95      0.88      0.91       185
#
#     accuracy                           0.93       439
#    macro avg       0.93      0.92      0.93       439
# weighted avg       0.93      0.93      0.93       439

# %% [markdown]
# #Model tuning

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    "C": [0.01, 0.1, 10, 100, 1000],
    "gamma": [0.001, 0.005, 0.1],
    "kernel": ["linear", "rbf", "poly", "sigmoid"]
}
gridsearch = make_pipeline(StandardScaler(), GridSearchCV(SVC(), param_grid, cv=5, scoring="f1", verbose=1)) #chọn số cv là 10 và score để đánh giá là f1
#Có thể tham khảo thêm svm ở đây
##.  https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# %%
gridsearch.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('gridsearchcv',
#                  GridSearchCV(cv=5, estimator=SVC(),
#                               param_grid={'C': [0.01, 0.1, 10, 100, 1000],
#                                           'gamma': [0.001, 0.005, 0.1],
#                                           'kernel': ['linear', 'rbf', 'poly',
#                                                      'sigmoid']},
#                               scoring='f1', verbose=1))])

# %%
#in ra param đc cho là tố nhất
gridsearch[1].best_params_
# Out:
# {'C': 100, 'gamma': 0.005, 'kernel': 'rbf'}

# %%
#Chạy lại svm theo các parameters tốt nhất
pipe_line = make_pipeline(StandardScaler(), SVC(C=100, gamma=0.005, kernel='rbf'))
pipe_line.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc', SVC(C=100, gamma=0.005))])

# %%
print(classification_report(y_test, pipe_line.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.97      0.95       254
#          1.0       0.96      0.90      0.93       185
#
#     accuracy                           0.94       439
#    macro avg       0.94      0.93      0.94       439
# weighted avg       0.94      0.94      0.94       439
